# %%
from PolarizationSimulator import *

# %%
mysim = SampleSimulator('../data/polarizationData_all.csv')

# %%
mysim.simulate('0_0_1', 10, 0)

# %%
mysim.simulate('0_0_1', 20, 0)

# %%
mysim.simulate('0_0_-1', 20, 0)

# %%
mysim.simulate('0_0_1', 40, 0)

# %%
mysim.simulate('0_0_1', 70, 0)

# %%
mysim.simulate('0_0_1', 89, 0)
