# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import matplotlib as mpl
mpl.rcParams['agg.path.chunksize'] = 10000

# %%
df = pd.read_csv("../data/polarizationData_all.csv")

# %%
df.plot(x = 'OutTheta', y = 'OutPhi')
plt.show()

# %%
df.plot(x = 'InTheta', y = 'InPhi')
plt.show()

# %%
df_theta21 = pd.read_csv("polarizationData_0_0_1_debug_theta21.csv")

# %%
df_theta21.plot(x = 'OutTheta', y = 'OutPhi')
plt.show()

# %%
df_theta21.plot(x = 'InTheta', y = 'InPhi')
plt.show()
